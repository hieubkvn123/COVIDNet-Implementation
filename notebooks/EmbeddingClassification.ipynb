# %% [markdown]
# # Change working directory

# %%
# %cd ..
# Out:
# /home/minhhieu/Desktop/Hieu/COVIDNet-Implementation

# %% [markdown]
# # Import libraries

# %%
import os
import tqdm
import pickle
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model

from sklearn.decomposition import PCA
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score, confusion_matrix

from dataloader import DataLoader
from contrastive import ArcFace, CosFace, SphereFace
from models import get_small_covid_net

visual_dir = 'media'

checkpoint_dir = 'checkpoints'
model_name = 'covid_net_test_contrastive_arcface_2'

model_path = 'best_model.h5'
weights_path = 'best_model.weights.h5'

train_dir = 'data/covidx/train'
test_dir = 'data/covidx/test'
img_size = 480
batch_size = 16

# %% [markdown]
# # Load the model

# %%
# Load raw model from weights and model path
model = load_model(os.path.join(checkpoint_dir, model_name, 'models', model_path),
                  custom_objects={'ArcFace' : ArcFace})
model.load_weights(os.path.join(checkpoint_dir, model_name, 'weights', weights_path))

# Get the embedding output only
model = Model(inputs=model.inputs[0], outputs=model.layers[-3].output, 
              name=f'{model.name}_Embedding')

print(model.summary())
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "Contrastive_COVID_Net_Small_Embedding"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 480, 480, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 240, 240, 56) 8288        input_1[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 240, 240, 56) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 120, 120, 56) 0           re_lu[0][0]
# __________________________________________________________________________________________________
# pepx_11 (Functional)            (None, 120, 120, 56) 6062        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 120, 120, 56) 3192        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp (None, 120, 120, 56) 0           pepx_11[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# pepx_12 (Functional)            (None, 120, 120, 56) 6062        tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow (None, 120, 120, 56) 0           pepx_11[0][0]
#                                                                  pepx_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow (None, 120, 120, 56) 0           tf_op_layer_AddV2_1[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 56)   0           pepx_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 60, 60, 56)   0           pepx_12[0][0]
# __________________________________________________________________________________________________
# pepx_13 (Functional)            (None, 120, 120, 56) 6062        tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow (None, 120, 120, 56) 0           pepx_11[0][0]
#                                                                  pepx_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_6 (TensorFlow (None, 60, 60, 56)   0           max_pooling2d_2[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 60, 60, 56)   0           pepx_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow (None, 120, 120, 56) 0           tf_op_layer_AddV2_3[0][0]
#                                                                  pepx_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_7 (TensorFlow (None, 60, 60, 56)   0           tf_op_layer_AddV2_6[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 60, 60, 56)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow (None, 120, 120, 56) 0           tf_op_layer_AddV2_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_8 (TensorFlow (None, 60, 60, 56)   0           tf_op_layer_AddV2_7[0][0]
#                                                                  max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 120, 120, 112 6384        tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# pepx_21 (Functional)            (None, 60, 60, 112)  7686        tf_op_layer_AddV2_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 60, 60, 112)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_9 (TensorFlow (None, 60, 60, 112)  0           pepx_21[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# pepx_22 (Functional)            (None, 60, 60, 112)  23100       tf_op_layer_AddV2_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_10 (TensorFlo (None, 60, 60, 112)  0           pepx_21[0][0]
#                                                                  pepx_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_11 (TensorFlo (None, 60, 60, 112)  0           tf_op_layer_AddV2_10[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# pepx_23 (Functional)            (None, 60, 60, 112)  23100       tf_op_layer_AddV2_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_12 (TensorFlo (None, 60, 60, 112)  0           pepx_21[0][0]
#                                                                  pepx_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_13 (TensorFlo (None, 60, 60, 112)  0           tf_op_layer_AddV2_12[0][0]
#                                                                  pepx_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 30, 30, 112)  0           pepx_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 30, 30, 112)  0           pepx_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_14 (TensorFlo (None, 60, 60, 112)  0           tf_op_layer_AddV2_13[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_15 (TensorFlo (None, 60, 60, 112)  0           pepx_21[0][0]
#                                                                  pepx_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_19 (TensorFlo (None, 30, 30, 112)  0           max_pooling2d_7[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 30, 30, 112)  0           pepx_23[0][0]
# __________________________________________________________________________________________________
# pepx_24 (Functional)            (None, 60, 60, 112)  23100       tf_op_layer_AddV2_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_16 (TensorFlo (None, 60, 60, 112)  0           tf_op_layer_AddV2_15[0][0]
#                                                                  pepx_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_20 (TensorFlo (None, 30, 30, 112)  0           tf_op_layer_AddV2_19[0][0]
#                                                                  max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 30, 30, 112)  0           pepx_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_17 (TensorFlo (None, 60, 60, 112)  0           tf_op_layer_AddV2_16[0][0]
#                                                                  pepx_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_21 (TensorFlo (None, 30, 30, 112)  0           tf_op_layer_AddV2_20[0][0]
#                                                                  max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 30, 30, 112)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_18 (TensorFlo (None, 60, 60, 112)  0           tf_op_layer_AddV2_17[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_22 (TensorFlo (None, 30, 30, 112)  0           tf_op_layer_AddV2_21[0][0]
#                                                                  max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 60, 60, 216)  24408       tf_op_layer_AddV2_18[0][0]
# __________________________________________________________________________________________________
# pepx_31 (Functional)            (None, 30, 30, 216)  29028       tf_op_layer_AddV2_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 30, 30, 216)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_23 (TensorFlo (None, 30, 30, 216)  0           pepx_31[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# pepx_32 (Functional)            (None, 30, 30, 216)  83862       tf_op_layer_AddV2_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_24 (TensorFlo (None, 30, 30, 216)  0           pepx_31[0][0]
#                                                                  pepx_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_25 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_24[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# pepx_33 (Functional)            (None, 30, 30, 216)  83862       tf_op_layer_AddV2_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_26 (TensorFlo (None, 30, 30, 216)  0           pepx_31[0][0]
#                                                                  pepx_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_27 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_26[0][0]
#                                                                  pepx_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_28 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_27[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_29 (TensorFlo (None, 30, 30, 216)  0           pepx_31[0][0]
#                                                                  pepx_32[0][0]
# __________________________________________________________________________________________________
# pepx_34 (Functional)            (None, 30, 30, 216)  83862       tf_op_layer_AddV2_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_30 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_29[0][0]
#                                                                  pepx_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_31 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_30[0][0]
#                                                                  pepx_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_33 (TensorFlo (None, 30, 30, 216)  0           pepx_31[0][0]
#                                                                  pepx_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_32 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_31[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_34 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_33[0][0]
#                                                                  pepx_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 15, 15, 216)  0           pepx_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 15, 15, 216)  0           pepx_32[0][0]
# __________________________________________________________________________________________________
# pepx_35 (Functional)            (None, 30, 30, 216)  83862       tf_op_layer_AddV2_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_35 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_34[0][0]
#                                                                  pepx_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_38 (TensorFlo (None, 30, 30, 216)  0           pepx_31[0][0]
#                                                                  pepx_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_44 (TensorFlo (None, 15, 15, 216)  0           max_pooling2d_13[0][0]
#                                                                  max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 15, 15, 216)  0           pepx_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_36 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_35[0][0]
#                                                                  pepx_35[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_39 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_38[0][0]
#                                                                  pepx_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_45 (TensorFlo (None, 15, 15, 216)  0           tf_op_layer_AddV2_44[0][0]
#                                                                  max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 15, 15, 216)  0           pepx_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_37 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_36[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_40 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_39[0][0]
#                                                                  pepx_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_46 (TensorFlo (None, 15, 15, 216)  0           tf_op_layer_AddV2_45[0][0]
#                                                                  max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 15, 15, 216)  0           pepx_35[0][0]
# __________________________________________________________________________________________________
# pepx_36 (Functional)            (None, 30, 30, 216)  83862       tf_op_layer_AddV2_37[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_41 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_40[0][0]
#                                                                  pepx_35[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_47 (TensorFlo (None, 15, 15, 216)  0           tf_op_layer_AddV2_46[0][0]
#                                                                  max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 15, 15, 216)  0           pepx_36[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_42 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_41[0][0]
#                                                                  pepx_36[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_48 (TensorFlo (None, 15, 15, 216)  0           tf_op_layer_AddV2_47[0][0]
#                                                                  max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 15, 15, 216)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_43 (TensorFlo (None, 30, 30, 216)  0           tf_op_layer_AddV2_42[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_49 (TensorFlo (None, 15, 15, 216)  0           tf_op_layer_AddV2_48[0][0]
#                                                                  max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 30, 30, 424)  92008       tf_op_layer_AddV2_43[0][0]
# __________________________________________________________________________________________________
# pepx_41 (Functional)            (None, 15, 15, 424)  106534      tf_op_layer_AddV2_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 15, 15, 424)  0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_50 (TensorFlo (None, 15, 15, 424)  0           pepx_41[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# pepx_42 (Functional)            (None, 15, 15, 424)  318954      tf_op_layer_AddV2_50[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_51 (TensorFlo (None, 15, 15, 424)  0           pepx_41[0][0]
#                                                                  pepx_42[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_52 (TensorFlo (None, 15, 15, 424)  0           tf_op_layer_AddV2_51[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_53 (TensorFlo (None, 15, 15, 424)  0           pepx_41[0][0]
#                                                                  pepx_42[0][0]
# __________________________________________________________________________________________________
# pepx_43 (Functional)            (None, 15, 15, 424)  318954      tf_op_layer_AddV2_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_54 (TensorFlo (None, 15, 15, 424)  0           tf_op_layer_AddV2_53[0][0]
#                                                                  pepx_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_55 (TensorFlo (None, 15, 15, 424)  0           tf_op_layer_AddV2_54[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 95400)        0           tf_op_layer_AddV2_55[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          48845312    flatten[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 512)          0           dense[0][0]
# ==================================================================================================
# Total params: 50,267,544
# Trainable params: 50,267,544
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Train a classifier on top of embeddings

# %%
# Load testing data
train_loader = DataLoader(train_dir, labels_as_subdir=True, one_hot=True,
            img_size=img_size,test=False,
            batch_size=batch_size, random_noise=True)

# Get number of batches
train_steps_per_epoch = train_loader.get_train_size()

# Loop through the batches
all_embeddings = np.array([])
all_labels = np.array([])

with tqdm.tqdm(total = train_steps_per_epoch) as pbar:
    for batchidx in range(train_steps_per_epoch):
        images, labels = train_loader.get_train_batch()
        images = images.numpy()
        labels = labels.numpy()
        
        embeddings = model(images, training=False)
        
        if(len(all_embeddings) != 0):
            all_embeddings = np.concatenate([all_embeddings, embeddings])
            all_labels = np.concatenate([all_labels, labels])
        else:
            all_embeddings = embeddings
            all_labels = labels
        
        pbar.update(1)
# Out:
# /home/minhhieu/.local/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:493: UserWarning: fill_value is not supported and is always 0 for TensorFlow < 2.4.0.
#   return py_builtins.overload_of(f)(*args)
# 100%|██████████| 1270/1270 [07:40<00:00,  2.76it/s]

# %%
# Normalize the train embeddings
all_embeddings = all_embeddings / np.linalg.norm(all_embeddings, axis=1).reshape(-1, 1)

# Train an SVM model
categories = np.argmax(all_labels, axis=1)
clf = SVC(kernel='linear', probability=True)
clf.fit(all_embeddings, categories)

# %%
# Save the classification model
if(not os.path.exists(os.path.join(checkpoint_dir, model_name, 'classifier'))):
    os.mkdir(os.path.join(checkpoint_dir, model_name, 'classifier'))
    print('[INFO] Classification model directiory created.')
    
with open(os.path.join(checkpoint_dir, model_name, 'classifier', 'clf.pickle'), 'wb') as f:
    pickle.dump(clf, f)
    print('[INFO] Classification model saved.')

# %% [markdown]
# # Test the classification model

# %%
# Load testing data
test_loader = DataLoader(test_dir, labels_as_subdir=True, one_hot=True,
            img_size=img_size,test=True,
            batch_size=batch_size, random_noise=False)

# Get number of batches
test_steps_per_epoch = test_loader.get_train_size()

# Loop through the batches
all_embeddings = np.array([])
all_labels = np.array([])

with tqdm.tqdm(total = test_steps_per_epoch) as pbar:
    for batchidx in range(test_steps_per_epoch):
        images, labels = test_loader.get_train_batch()
        images = images.numpy()
        labels = labels.numpy()
        
        embeddings = model(images, training=False)
        
        if(len(all_embeddings) != 0):
            all_embeddings = np.concatenate([all_embeddings, embeddings])
            all_labels = np.concatenate([all_labels, labels])
        else:
            all_embeddings = embeddings
            all_labels = labels
        
        pbar.update(1)

# %%
# Normalize all the embeddings
all_embeddings = all_embeddings / np.linalg.norm(all_embeddings, axis=1).reshape(-1, 1)

# Make predictions on the embeddings
predictions = clf.predict(all_embeddings)
